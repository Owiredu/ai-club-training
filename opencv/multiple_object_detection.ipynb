# %% [markdown]
# ### OBJECT DETECTION AND TRACKING WITH YOLOv5

# %%
# install the necessary libraries
import sys
# !{sys.executable} -m pip install jupyter
# !{sys.executable} -m pip install ipywidgets widgetsnbextension pandas-profiling
# !{sys.executable} -m pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# !{sys.executable} -m pip install pandas pyyaml tqdm seaborn numpy matplotlib opencv-contrib-python
# Out:
# Collecting jupyter
#   Downloading jupyter-1.0.0-py2.py3-none-any.whl (2.7 kB)
# Collecting nbconvert
#   Downloading nbconvert-7.0.0-py3-none-any.whl (271 kB)
#      ------------------------------------ 271.3/271.3 kB 881.9 kB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.1-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.7/133.7 kB 4.0 MB/s eta 0:00:00
# Collecting qtconsole
#   Downloading qtconsole-5.3.1-py3-none-any.whl (120 kB)
#      -------------------------------------- 120.8/120.8 kB 7.4 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.4.4-py3-none-any.whl (22 kB)
# Requirement already satisfied: ipykernel in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter) (6.15.1)
# Collecting notebook
#   Downloading notebook-6.4.12-py3-none-any.whl (9.9 MB)
#      ---------------------------------------- 9.9/9.9 MB 903.5 kB/s eta 0:00:00
# Requirement already satisfied: traitlets>=5.1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (5.3.0)
# Requirement already satisfied: ipython>=7.23.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (8.4.0)
# Requirement already satisfied: psutil in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (5.9.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (23.2.1)
# Requirement already satisfied: debugpy>=1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (1.6.2)
# Requirement already satisfied: tornado>=6.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: nest-asyncio in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (1.5.5)
# Requirement already satisfied: packaging in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel->jupyter) (21.3)
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.2-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 816.8 kB/s eta 0:00:00
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.2-py3-none-any.whl (383 kB)
#      ------------------------------------ 384.0/384.0 kB 920.5 kB/s eta 0:00:00
# Requirement already satisfied: pygments in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-console->jupyter) (2.13.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-console->jupyter) (3.0.30)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting mistune<3,>=2.0.3
#   Downloading mistune-2.0.4-py2.py3-none-any.whl (24 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.6.7-py3-none-any.whl (71 kB)
#      -------------------------------------- 71.8/71.8 kB 789.7 kB/s eta 0:00:00
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting lxml
#   Downloading lxml-4.9.1-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 741.4 kB/s eta 0:00:00
# Requirement already satisfied: jupyter-core>=4.7 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from nbconvert->jupyter) (4.11.1)
# Collecting tinycss2
#   Downloading tinycss2-1.1.1-py3-none-any.whl (21 kB)
# Collecting nbformat>=5.1
#   Downloading nbformat-5.4.0-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.3/73.3 kB 1.0 MB/s eta 0:00:00
# Collecting markupsafe>=2.0
#   Using cached MarkupSafe-2.1.1-cp310-cp310-win_amd64.whl (17 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.11.1-py3-none-any.whl (128 kB)
# Collecting bleach
#   Downloading bleach-5.0.1-py3-none-any.whl (160 kB)
#      ------------------------------------ 160.9/160.9 kB 875.9 kB/s eta 0:00:00
# Collecting jinja2>=3.0
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting prometheus-client
#   Downloading prometheus_client-0.14.1-py3-none-any.whl (59 kB)
#      -------------------------------------- 59.5/59.5 kB 631.3 kB/s eta 0:00:00
# Collecting Send2Trash>=1.8.0
#   Downloading Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting ipython-genutils
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.15.0-py3-none-any.whl (16 kB)
# Collecting qtpy>=2.0.1
#   Using cached QtPy-2.2.0-py3-none-any.whl (82 kB)
# Requirement already satisfied: colorama in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.5)
# Requirement already satisfied: pickleshare in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: decorator in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (58.1.0)
# Requirement already satisfied: backcall in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: stack-data in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.0)
# Requirement already satisfied: jedi>=0.16 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.18.1)
# Requirement already satisfied: entrypoints in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: pywin32>=1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-core>=4.7->nbconvert->jupyter) (304)
# Collecting jsonschema>=2.6
#   Downloading jsonschema-4.14.0-py3-none-any.whl (82 kB)
#      -------------------------------------- 82.4/82.4 kB 776.0 kB/s eta 0:00:00
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.16.1-py3-none-any.whl (22 kB)
# Requirement already satisfied: wcwidth in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.5)
# Collecting pywinpty>=1.1.0
#   Downloading pywinpty-2.0.7-cp310-none-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 859.0 kB/s eta 0:00:00
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-win_amd64.whl (30 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.3.2.post1-py3-none-any.whl (37 kB)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from bleach->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from packaging->ipykernel->jupyter) (3.0.9)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp310-cp310-win_amd64.whl (61 kB)
#      ---------------------------------------- 61.6/61.6 kB 1.1 MB/s eta 0:00:00
# Collecting attrs>=17.4.0
#   Downloading attrs-22.1.0-py2.py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.8/58.8 kB 1.0 MB/s eta 0:00:00
# Collecting cffi>=1.0.1
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Requirement already satisfied: pure-eval in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: asttokens in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.8)
# Requirement already satisfied: executing in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.10.0)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Installing collected packages: webencodings, Send2Trash, mistune, ipython-genutils, fastjsonschema, widgetsnbextension, tinycss2, soupsieve, pywinpty, pyrsistent, pycparser, prometheus-client, pandocfilters, markupsafe, lxml, jupyterlab-widgets, jupyterlab-pygments, defusedxml, bleach, attrs, terminado, qtpy, jsonschema, jinja2, cffi, beautifulsoup4, nbformat, argon2-cffi-bindings, nbclient, argon2-cffi, qtconsole, nbconvert, jupyter-console, ipywidgets, notebook, jupyter
# Successfully installed Send2Trash-1.8.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 attrs-22.1.0 beautifulsoup4-4.11.1 bleach-5.0.1 cffi-1.15.1 defusedxml-0.7.1 fastjsonschema-2.16.1 ipython-genutils-0.2.0 ipywidgets-8.0.1 jinja2-3.1.2 jsonschema-4.14.0 jupyter-1.0.0 jupyter-console-6.4.4 jupyterlab-pygments-0.2.2 jupyterlab-widgets-3.0.2 lxml-4.9.1 markupsafe-2.1.1 mistune-2.0.4 nbclient-0.6.7 nbconvert-7.0.0 nbformat-5.4.0 notebook-6.4.12 pandocfilters-1.5.0 prometheus-client-0.14.1 pycparser-2.21 pyrsistent-0.18.1 pywinpty-2.0.7 qtconsole-5.3.1 qtpy-2.2.0 soupsieve-2.3.2.post1 terminado-0.15.0 tinycss2-1.1.1 webencodings-0.5.1 widgetsnbextension-4.0.2
# Requirement already satisfied: ipywidgets in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (8.0.1)
# Requirement already satisfied: widgetsnbextension in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (4.0.2)
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
#      ------------------------------------ 262.6/262.6 kB 769.3 kB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets~=3.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipywidgets) (3.0.2)
# Requirement already satisfied: traitlets>=4.3.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipywidgets) (5.3.0)
# Requirement already satisfied: ipykernel>=4.5.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipywidgets) (6.15.1)
# Requirement already satisfied: ipython>=6.1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipywidgets) (8.4.0)
# Requirement already satisfied: tqdm>=4.48.2 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (4.64.0)
# Collecting missingno>=0.4.2
#   Downloading missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: markupsafe~=2.1.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (2.1.1)
# Collecting visions[type_image_path]==0.7.4
#   Downloading visions-0.7.4-py3-none-any.whl (102 kB)
#      -------------------------------------- 102.4/102.4 kB 3.0 MB/s eta 0:00:00
# Collecting joblib~=1.1.0
#   Using cached joblib-1.1.0-py2.py3-none-any.whl (306 kB)
# Requirement already satisfied: jinja2>=2.11.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (3.1.2)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp310-cp310-win_amd64.whl (703 kB)
#      -------------------------------------- 703.8/703.8 kB 1.1 MB/s eta 0:00:00
# Collecting multimethod>=1.4
#   Downloading multimethod-1.8-py3-none-any.whl (9.8 kB)
# Collecting pydantic>=1.8.1
#   Using cached pydantic-1.9.2-cp310-cp310-win_amd64.whl (2.0 MB)
# Requirement already satisfied: matplotlib>=3.2.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (3.5.3)
# Requirement already satisfied: PyYAML>=5.0.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: requests>=2.24.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (2.28.1)
# Requirement already satisfied: scipy>=1.4.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (1.9.0)
# Requirement already satisfied: seaborn>=0.10.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (0.11.2)
# Collecting tangled-up-in-unicode==0.2.0
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#      ---------------------------------------- 4.7/4.7 MB 1.1 MB/s eta 0:00:00
# Collecting htmlmin>=0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (1.4.3)
# Requirement already satisfied: numpy>=1.16.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas-profiling) (1.23.2)
# Collecting networkx>=2.4
#   Downloading networkx-2.8.6-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 699.8 kB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.3.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (22.1.0)
# Requirement already satisfied: Pillow in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (9.2.0)
# Collecting imagehash
#   Downloading ImageHash-4.2.1.tar.gz (812 kB)
#      ------------------------------------ 812.6/812.6 kB 438.9 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (7.3.4)
# Requirement already satisfied: packaging in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (21.3)
# Requirement already satisfied: tornado>=6.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (6.2)
# Requirement already satisfied: pyzmq>=17 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (23.2.1)
# Requirement already satisfied: nest-asyncio in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.5)
# Requirement already satisfied: psutil in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.30)
# Requirement already satisfied: decorator in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: stack-data in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.0)
# Requirement already satisfied: setuptools>=18.5 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (58.1.0)
# Requirement already satisfied: colorama in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.5)
# Requirement already satisfied: backcall in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.18.1)
# Requirement already satisfied: pygments>=2.4.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.13.0)
# Requirement already satisfied: pickleshare in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.36.0)
# Requirement already satisfied: pytz>=2020.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2022.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.3.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests>=2.24.0->pandas-profiling) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: entrypoints in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.11.1)
# Requirement already satisfied: wcwidth in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: six>=1.5 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.16.0)
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 604.6 kB/s eta 0:00:00
# Requirement already satisfied: executing in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.10.0)
# Requirement already satisfied: pure-eval in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: asttokens in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.8)
# Requirement already satisfied: pywin32>=1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (304)
# Using legacy 'setup.py install' for htmlmin, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for imagehash, since package 'wheel' is not installed.
# Installing collected packages: htmlmin, tangled-up-in-unicode, PyWavelets, pydantic, networkx, multimethod, joblib, imagehash, visions, phik, missingno, pandas-profiling
#   Running setup.py install for htmlmin: started
#   Running setup.py install for htmlmin: finished with status 'done'
#   Running setup.py install for imagehash: started
#   Running setup.py install for imagehash: finished with status 'done'
# Successfully installed PyWavelets-1.3.0 htmlmin-0.1.12 imagehash-4.2.1 joblib-1.1.0 missingno-0.5.1 multimethod-1.8 networkx-2.8.6 pandas-profiling-3.2.0 phik-0.12.2 pydantic-1.9.2 tangled-up-in-unicode-0.2.0 visions-0.7.4
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Requirement already satisfied: torch in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (1.12.1+cu116)
# Requirement already satisfied: torchvision in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (0.13.1+cu116)
# Requirement already satisfied: torchaudio in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (0.12.1+cu116)
# Requirement already satisfied: typing-extensions in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from torch) (4.3.0)
# Requirement already satisfied: requests in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from torchvision) (9.2.0)
# Requirement already satisfied: numpy in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from torchvision) (1.23.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests->torchvision) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests->torchvision) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: pandas in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (1.4.3)
# Requirement already satisfied: pyyaml in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (6.0)
# Requirement already satisfied: tqdm in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (4.64.0)
# Requirement already satisfied: seaborn in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (0.11.2)
# Requirement already satisfied: numpy in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (1.23.2)
# Requirement already satisfied: matplotlib in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (3.5.3)
# Requirement already satisfied: opencv-contrib-python in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (4.6.0.66)
# Requirement already satisfied: python-dateutil>=2.8.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: colorama in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from tqdm) (0.4.5)
# Requirement already satisfied: scipy>=1.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from seaborn) (1.9.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib) (4.36.0)
# Requirement already satisfied: pillow>=6.2.0 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: six>=1.5 in d:\documents\ai-club\ai-club-training\opencv\venv\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# clone the YOLOv5 repo
# !git clone https://github.com/ultralytics/yolov5  # clone
# Out:
# fatal: Too many arguments.
#
# usage: git clone [<options>] [--] <repo> [<dir>]
#
#     -v, --verbose         be more verbose
#     -q, --quiet           be more quiet
#     --progress            force progress reporting
#     --reject-shallow      don't clone shallow repository
#     -n, --no-checkout     don't create a checkout
#     --bare                create a bare repository
#     --mirror              create a mirror repository (implies bare)
#     -l, --local           to clone from a local repository
#     --no-hardlinks        don't use local hardlinks, always copy
#     -s, --shared          setup as shared repository
#     --recurse-submodules[=<pathspec>]
#                           initialize submodules in the clone
#     --recursive ...       alias of --recurse-submodules
#     -j, --jobs <n>        number of submodules cloned in parallel
#     --template <template-directory>
#                           directory from which templates will be used
#     --reference <repo>    reference repository
#     --reference-if-able <repo>
#                           reference repository
#     --dissociate          use --reference only while cloning
#     -o, --origin <name>   use <name> instead of 'origin' to track upstream
#     -b, --branch <branch>
#                           checkout <branch> instead of the remote's HEAD
#     -u, --upload-pack <path>
#                           path to git-upload-pack on the remote
#     --depth <depth>       create a shallow clone of that depth
#     --shallow-since <time>
#                           create a shallow clone since a specific time
#     --shallow-exclude <revision>
#                           deepen history of shallow clone, excluding rev
#     --single-branch       clone only one branch, HEAD or --branch
#     --no-tags             don't clone any tags, and make later fetches not to follow them
#     --shallow-submodules  any cloned submodules will be shallow
#     --separate-git-dir <gitdir>
#                           separate git dir from working tree
#     -c, --config <key=value>
#                           set config inside the new repository
#     --server-option <server-specific>
#                           option to transmit
#     -4, --ipv4            use IPv4 addresses only
#     -6, --ipv6            use IPv6 addresses only
#     --filter <args>       object filtering
#     --also-filter-submodules
#                           apply partial clone filters to submodules
#     --remote-submodules   any cloned submodules will use their remote-tracking branch
#     --sparse              initialize sparse-checkout file to include only files at root

# %%
# import libraries
import cv2
import torch

# %%
# load model (reference: https://github.com/ultralytics/yolov5)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom
# Out:
# Using cache found in C:\Users\Nana Kofi Owiredu/.cache\torch\hub\ultralytics_yolov5_master
# requirements: protobuf<=3.20.1 not found and is required by YOLOv5, attempting auto-update...
# requirements: Command 'pip install "protobuf<=3.20.1" ' returned non-zero exit status 1.
# YOLOv5  2022-8-23 Python-3.10.5 torch-1.12.1+cu116 CUDA:0 (GeForce GTX 1650 with Max-Q Design, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# #### WITH IMAGES

# %%
# get image
img = cv2.imread('images/img-4.jpg')  # or file, Path, PIL, OpenCV, numpy, list
# make inference
results = model(img)
# get the results as a pandas dataframe
result_df = results.pandas().xyxy[0]

# filter out object detections
# supported objects:
# - person
# - bird, cat, cow, dog, horse, sheep
# - aeroplane, bicycle, boat, bus, car, motorbike, train
# - bottle, chair, dining table, potted plant, sofa, tv/monitor
objects = result_df
# objects = result_df[result_df["name"] == "person"]

# loop over the detections
for i in range(objects.shape[0]):
    # get a detected person detection data
    object_row = objects.iloc[i]
    start_x = int(object_row["xmin"])
    start_y = int(object_row["ymin"])
    end_x = int(object_row["xmax"])
    end_y = int(object_row["ymax"])
    confidence = round(object_row["confidence"], 2) * 100
    
    # print object name, coords and confidence
    print(f"name: {object_row['name']} |", f"coords: {start_x, start_y, end_x, end_y}", f"| confidence: {confidence}%")
    
    # fish out only results with confidence >= 50%
    if object_row["confidence"] >= 0.5:
        # draw a rectangle
        img = cv2.rectangle(
            img=img.copy(), 
            pt1=(start_x, start_y), 
            pt2=(end_x, end_y), 
            color=(255, 0, 0), 
            thickness=3,
            lineType=cv2.LINE_AA
        )
        
        # write the name of the object on it's bounding box
        # put text on the image
        img = cv2.putText(
            img=img.copy(), 
            text=f"{object_row['name']} ({confidence}%)", 
            org=(start_x, start_y), 
            fontFace=cv2.FONT_HERSHEY_COMPLEX, 
            fontScale=1, 
            color=(0, 255, 0), 
            thickness=3, 
            lineType=cv2.LINE_AA
        )
    
# show resulting image
cv2.imshow("Video", img)

# wait 30 milliseconds for a key press event
keypressed = cv2.waitKey(0)
# if the ESC key is pressed, destroy all windows
if keypressed == 27:
    # destroy all windows
    cv2.destroyAllWindows()
# Out:
# name: dog | coords: (691, 255, 984, 1045) | confidence: 91.0%
# name: person | coords: (984, 112, 1515, 937) | confidence: 89.0%
# name: car | coords: (348, 494, 517, 569) | confidence: 34.0%
# name: person | coords: (1145, 471, 1291, 591) | confidence: 32.0%

# %% [markdown]
# #### WITH VIDEOS

# %%
# start video capture
capture = cv2.VideoCapture(0)

# check whether the capture was opened successfully
if not capture.isOpened():
    print("Unable to start camera")

# initialize frame tracker and frame holders
frames_tracker = 0
previous_frame, current_frame, next_frame = None, None, None

while True:
    # capture the next frame
    ret, frame = capture.read()
    
    # check whether the frame is available or not
    if frame is None:
        break
    
    ############################### BEGIN OBJECT DETECTION
    
    # make inference
    results = model(frame)
    # get the results as a pandas dataframe
    result_df = results.pandas().xyxy[0]

    # filter out object detections
    # supported objects:
    # - person
    # - bird, cat, cow, dog, horse, sheep
    # - aeroplane, bicycle, boat, bus, car, motorbike, train
    # - bottle, chair, dining table, potted plant, sofa, tv/monitor
    objects = result_df
    # objects = result_df[result_df["name"] == "person"]

    # loop over the detections
    for i in range(objects.shape[0]):
        # get a detected person detection data
        object_row = objects.iloc[i]
        start_x = int(object_row["xmin"])
        start_y = int(object_row["ymin"])
        end_x = int(object_row["xmax"])
        end_y = int(object_row["ymax"])
        confidence = round(object_row["confidence"], 2) * 100
        
        # fish out only results with confidence >= 50%
        if object_row["confidence"] >= 0.5:
            # draw a rectangle
            frame = cv2.rectangle(
                img=frame.copy(), 
                pt1=(start_x, start_y), 
                pt2=(end_x, end_y), 
                color=(255, 0, 0), 
                thickness=3,
                lineType=cv2.LINE_AA
            )
            
            # write the name of the object on it's bounding box
            # put text on the image
            frame = cv2.putText(
                img=frame.copy(), 
                text=f"{object_row['name']} ({confidence}%)", 
                org=(start_x, start_y), 
                fontFace=cv2.FONT_HERSHEY_COMPLEX, 
                fontScale=1, 
                color=(0, 255, 0), 
                thickness=3, 
                lineType=cv2.LINE_AA
            )
    
    ############################### END OBJECT DETECTION
    
    # show the captured frame
    cv2.imshow("Video", frame)
    
    # wait 30 milliseconds for a key press event
    keypressed = cv2.waitKey(30)
    # if the ESC key is pressed, destroy all windows and release resources
    if keypressed == 27:
        # release camera
        capture.release()
        # destroy all windows
        cv2.destroyAllWindows()
        break
